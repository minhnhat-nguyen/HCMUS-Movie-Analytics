# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../data/cleaned_movies.csv')
df.head(5)
# Out:
#           original_title  popularity                  title  vote_average  \
# 0  Venom: The Last Dance    3197.278  Venom: The Last Dance         6.500
# 1            Terrifier 3    2204.248            Terrifier 3         6.925
# 2         The Wild Robot    1868.856         The Wild Robot         8.500
# 3   Deadpool & Wolverine    1490.952   Deadpool & Wolverine         7.700
# 4          The Substance    1356.547          The Substance         7.273
#
#    vote_count     budget     imdb_id  \
# 0         759  120000000  tt16366836
# 1        1012    2000000  tt27911000
# 2        2899   78000000  tt29623480
# 3        5465  200000000   tt6263850
# 4        2048   17500000  tt17526714
#
#                                 production_companies  runtime  \
# 0  Columbia Pictures, Pascal Pictures, Matt Tolma...      109
# 1  Cineverse, Bloody Disgusting, Dark Age Cinema,...      125
# 2                               DreamWorks Animation      102
# ...

# %%
matrix = df.drop(columns=['original_title', 'title', 'imdb_id', 'production_companies']).corr()
plt.figure(figsize=(16, 16))  # Kích thước biểu đồ
sns.heatmap(matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()
